# %% [markdown]
# ## Do you use spreadsheets in your job or want to find info from data for your own pleasure?
#
# ## Do you wish there were a better way?
#
# ## There is a better way to handle that data with Pandas.  Pandas is spreadsheets for Python.

# %%
import pandas as pd

# %% [markdown]
# ## Last time we were talking about Numpy and this time around we will be moving up the stack of the data science stack for Python to Pandas.

# %%
from IPython.display import Image
from IPython.core.display import HTML
Image(url="Python-datasci.jpg", width=600, height=600)
# Out:
# <img src="Python-datasci.jpg" width="600" height="600"/>

# %% [markdown]
# ## I whole heartedly recommend diving in to data especially when it's local government data.  This dataset I'll be using is from the data.SanDiego.gov site.

# %%
parking_meters = pd.read_csv('treas_parking_meters_loc_datasd.csv')

# %%
parking_meters
# Out:
#         zone            area                sub_area      pole  config_code  \
# 0       City    Barrio Logan         2900 ADDISON ST  ADN-2912         9116
# 1       City    Barrio Logan         2900 ADDISON ST  ADN-2914         9116
# 2       City    Barrio Logan   1000 CESAR CHAVEZ WAY   CC-1003         9000
# 3       City    Barrio Logan   1000 CESAR CHAVEZ WAY   CC-1005         9000
# 4       City    Barrio Logan   1000 CESAR CHAVEZ WAY   CC-1011         9000
# 5       City    Barrio Logan   1000 CESAR CHAVEZ WAY   CC-1013         9000
# 6       City    Barrio Logan   1000 CESAR CHAVEZ WAY   CC-1015         9000
# 7       City    Barrio Logan   1000 CESAR CHAVEZ WAY   CC-1017         9000
# 8       City    Barrio Logan   1000 CESAR CHAVEZ WAY   CC-1019         9000
# 9       City    Barrio Logan   1100 CESAR CHAVEZ WAY   CC-1103         9000
# 10      City    Barrio Logan   1100 CESAR CHAVEZ WAY   CC-1105         9000
# 11      City    Barrio Logan   1100 CESAR CHAVEZ WAY   CC-1107         9000
# 12      City    Barrio Logan   1100 CESAR CHAVEZ WAY   CC-1109         9000
# 13      City    Barrio Logan   1100 CESAR CHAVEZ WAY   CC-1111         9000
# 14      City    Barrio Logan   1100 CESAR CHAVEZ WAY   CC-1115         9000
# 15      City    Barrio Logan   1100 CESAR CHAVEZ WAY   CC-1117         9000
# 16      City    Barrio Logan            1800 MAIN ST   MN-1827         9000
# 17      City    Barrio Logan            1800 MAIN ST   MN-1829         9000
# 18      City    Barrio Logan            2800 MAIN ST   MN-2808         9000
# 19      City    Barrio Logan            2800 MAIN ST   MN-2812         9000
# 20      City    Barrio Logan            2800 MAIN ST   MN-2814         9000
# 21      City    Barrio Logan            2800 MAIN ST   MN-2816         9000
# 22      City    Barrio Logan            2800 MAIN ST   MN-2824         9000
# 23      City    Barrio Logan            2800 MAIN ST   MN-2826         9000
# 24      City    Barrio Logan            2800 MAIN ST   MN-2828         9000
# 25      City    Barrio Logan            2800 MAIN ST   MN-2830         9000
# 26      City    Barrio Logan            2800 MAIN ST   MN-2838         9000
# 27      City    Barrio Logan            2800 MAIN ST   MN-2840         9000
# 28      City    Barrio Logan            2800 MAIN ST   MN-2842         9000
# 29      City    Barrio Logan       1700 NATIONAL AVE   NL-1701         9000
# ...      ...             ...                     ...       ...          ...
# 4623  Uptown   Mission Hills  900 WEST WASHINGTON ST    WN-913        12494
# 4624  Uptown   Mission Hills  900 WEST WASHINGTON ST    WN-915        12494
# 4625  Uptown   Normal Street         3900 block West  NR-3900W        13503
# 4626  Uptown  University Hei         1700 MONROE AVE   MO-1729         8999
# 4627  Uptown  University Hei         1700 MONROE AVE   MO-1732         8999
# 4628  Uptown  University Hei         1700 MONROE AVE   MO-1734         8999
# 4629  Uptown  University Hei         1700 MONROE AVE   MO-1737         8999
# 4630  Uptown  University Hei          4400 PARK BLVD   PB-4405         9000
# 4631  Uptown  University Hei          4400 PARK BLVD   PB-4407         9000
# 4632  Uptown  University Hei          4400 PARK BLVD   PB-4409         9000
# 4633  Uptown  University Hei          4400 PARK BLVD   PB-4411         9000
# 4634  Uptown  University Hei          4400 PARK BLVD   PB-4428         9000
# 4635  Uptown  University Hei          4400 PARK BLVD   PB-4430         9000
# 4636  Uptown  University Hei          4400 PARK BLVD   PB-4432         9000
# 4637  Uptown  University Hei          4400 PARK BLVD   PB-4434         9000
# 4638  Uptown  University Hei          4400 PARK BLVD   PB-4436         9000
# 4639  Uptown  University Hei          4400 PARK BLVD   PB-4442         9116
# 4640  Uptown  University Hei          4400 PARK BLVD   PB-4444         9116
# 4641  Uptown  University Hei          4500 PARK BLVD   PB-4501         9000
# 4642  Uptown  University Hei          4500 PARK BLVD   PB-4503         9000
# 4643  Uptown  University Hei          4500 PARK BLVD   PB-4542         9000
# 4644  Uptown  University Hei          4500 PARK BLVD   PB-4544         9000
# 4645  Uptown  University Hei          4600 PARK BLVD   PB-4612         9000
# 4646  Uptown  University Hei          4600 PARK BLVD   PB-4614         9000
# 4647  Uptown  University Hei          4600 PARK BLVD   PB-4616         9000
# 4648  Uptown  University Hei          4600 PARK BLVD   PB-4618         9000
# 4649  Uptown  University Hei          4600 PARK BLVD   PB-4622         9000
# 4650  Uptown  University Hei          4600 PARK BLVD   PB-4631         9000
# 4651  Uptown  University Hei          4600 PARK BLVD   PB-4633         9000
# 4652  Uptown  University Hei          4600 PARK BLVD   PB-4635         9000
#
#                                            config_name   longitude   latitude
# 0                  30 Min Max $1.25 HR 8am-6pm Mon-Sat -117.230904  32.721670
# 1                  30 Min Max $1.25 HR 8am-6pm Mon-Sat -117.230913  32.721575
# 2                  2 Hour Max $1.25 HR 8am-6pm Mon-Sat -117.145178  32.700353
# 3                  2 Hour Max $1.25 HR 8am-6pm Mon-Sat -117.145178  32.700352
# 4                  2 Hour Max $1.25 HR 8am-6pm Mon-Sat -117.145349  32.700155
# 5                  2 Hour Max $1.25 HR 8am-6pm Mon-Sat -117.145405  32.700107
# 6                  2 Hour Max $1.25 HR 8am-6pm Mon-Sat -117.145539  32.699987
# 7                  2 Hour Max $1.25 HR 8am-6pm Mon-Sat -117.145540  32.699985
# 8                  2 Hour Max $1.25 HR 8am-6pm Mon-Sat -117.145545  32.699981
# 9                  2 Hour Max $1.25 HR 8am-6pm Mon-Sat -117.145973  32.699544
# 10                 2 Hour Max $1.25 HR 8am-6pm Mon-Sat -117.145973  32.699545
# 11                 2 Hour Max $1.25 HR 8am-6pm Mon-Sat -117.146065  32.699490
# 12                 2 Hour Max $1.25 HR 8am-6pm Mon-Sat -117.146065  32.699491
# 13                 2 Hour Max $1.25 HR 8am-6pm Mon-Sat -117.145915  32.699629
# 14                 2 Hour Max $1.25 HR 8am-6pm Mon-Sat -117.145978  32.699501
# 15                 2 Hour Max $1.25 HR 8am-6pm Mon-Sat -117.146053  32.699556
# 16                 2 Hour Max $1.25 HR 8am-6pm Mon-Sat -117.147804  32.699751
# 17                 2 Hour Max $1.25 HR 8am-6pm Mon-Sat -117.147282  32.699391
# 18                 2 Hour Max $1.25 HR 8am-6pm Mon-Sat -117.133469  32.692883
# 19                 2 Hour Max $1.25 HR 8am-6pm Mon-Sat -117.133316  32.692886
# 20                 2 Hour Max $1.25 HR 8am-6pm Mon-Sat -117.133124  32.692890
# 21                 2 Hour Max $1.25 HR 8am-6pm Mon-Sat -117.132968  32.692891
# 22                 2 Hour Max $1.25 HR 8am-6pm Mon-Sat -117.132815  32.692891
# 23                 2 Hour Max $1.25 HR 8am-6pm Mon-Sat -117.132661  32.692892
# 24                 2 Hour Max $1.25 HR 8am-6pm Mon-Sat -117.132508  32.692892
# 25                 2 Hour Max $1.25 HR 8am-6pm Mon-Sat -117.132354  32.692892
# 26                 2 Hour Max $1.25 HR 8am-6pm Mon-Sat -117.132162  32.692892
# 27                 2 Hour Max $1.25 HR 8am-6pm Mon-Sat -117.132009  32.692892
# 28                 2 Hour Max $1.25 HR 8am-6pm Mon-Sat -117.131855  32.692893
# 29                 2 Hour Max $1.25 HR 8am-6pm Mon-Sat -117.148149  32.702693
# ...                                                ...         ...        ...
# 4623                     PBP Pilot Copy of Config 9000 -117.155341  32.750315
# 4624                     PBP Pilot Copy of Config 9000 -117.155300  32.750320
# 4625  MSPM 8 Hour Max $0.50 HR 8am-6pm Mon-Sat (Normal -117.149673  32.748761
# 4626               1 Hour Max $1.25 HR 8am-6pm Mon-Sat -117.146760  32.759032
# 4627               1 Hour Max $1.25 HR 8am-6pm Mon-Sat -117.146550  32.759207
# 4628               1 Hour Max $1.25 HR 8am-6pm Mon-Sat -117.146514  32.759195
# 4629               1 Hour Max $1.25 HR 8am-6pm Mon-Sat -117.146457  32.759051
# 4630               2 Hour Max $1.25 HR 8am-6pm Mon-Sat -117.146154  32.757706
# 4631               2 Hour Max $1.25 HR 8am-6pm Mon-Sat -117.146170  32.757771
# 4632               2 Hour Max $1.25 HR 8am-6pm Mon-Sat -117.146247  32.757697
# 4633               2 Hour Max $1.25 HR 8am-6pm Mon-Sat -117.146033  32.757840
# 4634               2 Hour Max $1.25 HR 8am-6pm Mon-Sat -117.146303  32.758444
# 4635               2 Hour Max $1.25 HR 8am-6pm Mon-Sat -117.146333  32.758516
# 4636               2 Hour Max $1.25 HR 8am-6pm Mon-Sat -117.146348  32.758603
# 4637               2 Hour Max $1.25 HR 8am-6pm Mon-Sat -117.146337  32.758677
# 4638               2 Hour Max $1.25 HR 8am-6pm Mon-Sat -117.146344  32.758751
# 4639               30 Min Max $1.25 HR 8am-6pm Mon-Sat -117.146366  32.758907
# 4640               30 Min Max $1.25 HR 8am-6pm Mon-Sat -117.146343  32.758930
# 4641               2 Hour Max $1.25 HR 8am-6pm Mon-Sat -117.146293  32.759215
# 4642               2 Hour Max $1.25 HR 8am-6pm Mon-Sat -117.146182  32.759404
# 4643               2 Hour Max $1.25 HR 8am-6pm Mon-Sat -117.146364  32.760823
# 4644               2 Hour Max $1.25 HR 8am-6pm Mon-Sat -117.146381  32.760837
# 4645               2 Hour Max $1.25 HR 8am-6pm Mon-Sat -117.146240  32.761347
# 4646               2 Hour Max $1.25 HR 8am-6pm Mon-Sat -117.146381  32.761526
# 4647               2 Hour Max $1.25 HR 8am-6pm Mon-Sat -117.146246  32.761377
# 4648               2 Hour Max $1.25 HR 8am-6pm Mon-Sat -117.146344  32.761601
# 4649               2 Hour Max $1.25 HR 8am-6pm Mon-Sat -117.146241  32.761375
# 4650               2 Hour Max $1.25 HR 8am-6pm Mon-Sat -117.146185  32.762074
# 4651               2 Hour Max $1.25 HR 8am-6pm Mon-Sat -117.146180  32.762115
# 4652               2 Hour Max $1.25 HR 8am-6pm Mon-Sat -117.146182  32.762184
#
# [4653 rows x 8 columns]

# %% [markdown]
# You can read many file formats.  CSV is one of the most popular, others are JSON, HDF if you are working on Scientific work, and of course Excel.

# %% [markdown]
# ## Why would you use this over something like Excel?

# %% [markdown]
# You would use this when you didn't want to be limited by the number of Rows or columns that can be handled by Excel.  Pandas can take use of your whole RAM.

# %% [markdown]
# ## How would using this be different than using a spreadsheet application?

# %% [markdown]
# This doesn't operate on one cell at a time.  You have to think about the entire row or column. Let me show some samples:

# %%
parking_meters.head()
# Out:
#    zone          area               sub_area      pole  config_code  \
# 0  City  Barrio Logan        2900 ADDISON ST  ADN-2912         9116
# 1  City  Barrio Logan        2900 ADDISON ST  ADN-2914         9116
# 2  City  Barrio Logan  1000 CESAR CHAVEZ WAY   CC-1003         9000
# 3  City  Barrio Logan  1000 CESAR CHAVEZ WAY   CC-1005         9000
# 4  City  Barrio Logan  1000 CESAR CHAVEZ WAY   CC-1011         9000
#
#                            config_name   longitude   latitude
# 0  30 Min Max $1.25 HR 8am-6pm Mon-Sat -117.230904  32.721670
# 1  30 Min Max $1.25 HR 8am-6pm Mon-Sat -117.230913  32.721575
# 2  2 Hour Max $1.25 HR 8am-6pm Mon-Sat -117.145178  32.700353
# 3  2 Hour Max $1.25 HR 8am-6pm Mon-Sat -117.145178  32.700352
# 4  2 Hour Max $1.25 HR 8am-6pm Mon-Sat -117.145349  32.700155

# %% [markdown]
# ## OH NO.  We find out from NASA that the satelites are off by -1 degree longitude for our San Diego Parking Meter dataset.  We can fix the whole column by changing the values.

# %%
parking_meters['old longitude'] = parking_meters['longitude']
parking_meters['longitude'] = parking_meters['longitude'] - 1 #using Python's right to left evaluation
parking_meters.head()
# Out:
#    zone          area               sub_area      pole  config_code  \
# 0  City  Barrio Logan        2900 ADDISON ST  ADN-2912         9116
# 1  City  Barrio Logan        2900 ADDISON ST  ADN-2914         9116
# 2  City  Barrio Logan  1000 CESAR CHAVEZ WAY   CC-1003         9000
# 3  City  Barrio Logan  1000 CESAR CHAVEZ WAY   CC-1005         9000
# 4  City  Barrio Logan  1000 CESAR CHAVEZ WAY   CC-1011         9000
#
#                            config_name   longitude   latitude  old longitude
# 0  30 Min Max $1.25 HR 8am-6pm Mon-Sat -118.230904  32.721670    -117.230904
# 1  30 Min Max $1.25 HR 8am-6pm Mon-Sat -118.230913  32.721575    -117.230913
# 2  2 Hour Max $1.25 HR 8am-6pm Mon-Sat -118.145178  32.700353    -117.145178
# 3  2 Hour Max $1.25 HR 8am-6pm Mon-Sat -118.145178  32.700352    -117.145178
# 4  2 Hour Max $1.25 HR 8am-6pm Mon-Sat -118.145349  32.700155    -117.145349

# %% [markdown]
# ### The example above shows the core of the DataFrame Mindset.  Work on the entire column at once or build a new column for the new data.  In Excel you would have to build a formula into a cell like the image below.  Then you would see the new value once it was run.

# %%
Image(url="Excel.png", width=600, height=600)
# Out:
# <img src="Excel.png" width="600" height="600"/>

# %% [markdown]
# ### In Excel if the longitude value changes, then the "New Longitude" value changes as well.  Excel is dynamic on a cell by cell basis, Every cell could have a different function in it for calculating the "New Longitude".  So Excel has to evaluate the function that is to be run on the data EVERY TIME.   This is probematic for large amounts of changes (Excel slows to a crawl and sometimes crashes).  In Pandas our functions are removed from the data.  So Excel runs lots of functions on lots of data, Pandas runs one function on lots of data.  Which one is faster?  The one that doesn't have to re-evaluate the function for every value.

# %%
parking_meters.head()
# Out:
#    zone          area               sub_area      pole  config_code  \
# 0  City  Barrio Logan        2900 ADDISON ST  ADN-2912         9116
# 1  City  Barrio Logan        2900 ADDISON ST  ADN-2914         9116
# 2  City  Barrio Logan  1000 CESAR CHAVEZ WAY   CC-1003         9000
# 3  City  Barrio Logan  1000 CESAR CHAVEZ WAY   CC-1005         9000
# 4  City  Barrio Logan  1000 CESAR CHAVEZ WAY   CC-1011         9000
#
#                            config_name   longitude   latitude  old longitude
# 0  30 Min Max $1.25 HR 8am-6pm Mon-Sat -118.230904  32.721670    -117.230904
# 1  30 Min Max $1.25 HR 8am-6pm Mon-Sat -118.230913  32.721575    -117.230913
# 2  2 Hour Max $1.25 HR 8am-6pm Mon-Sat -118.145178  32.700353    -117.145178
# 3  2 Hour Max $1.25 HR 8am-6pm Mon-Sat -118.145178  32.700352    -117.145178
# 4  2 Hour Max $1.25 HR 8am-6pm Mon-Sat -118.145349  32.700155    -117.145349

# %% [markdown]
# ## We can see information about the numerical columns by doing a describe() operation.

# %%
parking_meters.describe()
# Out:
#         config_code    longitude     latitude  old longitude
# count   4653.000000  4653.000000  4653.000000    4653.000000
# mean    9878.291640  -118.158759    32.725719    -117.158759
# std     2426.385073     0.011064     0.014705       0.011064
# min       66.000000  -118.250691    32.692883    -117.250691
# 25%     9000.000000  -118.162132    32.713908    -117.162132
# 50%     9000.000000  -118.160311    32.720325    -117.160311
# 75%    12494.000000  -118.156588    32.736694    -117.156588
# max    13652.000000  -118.070775    32.772126    -117.070775

# %% [markdown]
# ## The data types of this dataFrame are as follows.  If you remember from last time, this information can be used to speed up slow operations by reducing the amount of memory a particular column is using by changing the data type.

# %%
parking_meters.dtypes
# Out:
# zone              object
# area              object
# sub_area          object
# pole              object
# config_code        int64
# config_name       object
# longitude        float64
# latitude         float64
# old longitude    float64
# dtype: object

# %%
import numpy as np
parking_meters['config_code'] = parking_meters['config_code'].astype(np.int16)

# %% [markdown]
# ## And now when you look at the Dtypes you will see the config_code has changed type.

# %%
parking_meters.dtypes
# Out:
# zone              object
# area              object
# sub_area          object
# pole              object
# config_code        int16
# config_name       object
# longitude        float64
# latitude         float64
# old longitude    float64
# dtype: object

# %%
parking_meters.head()
# Out:
#    zone          area               sub_area      pole  config_code  \
# 0  City  Barrio Logan        2900 ADDISON ST  ADN-2912         9116
# 1  City  Barrio Logan        2900 ADDISON ST  ADN-2914         9116
# 2  City  Barrio Logan  1000 CESAR CHAVEZ WAY   CC-1003         9000
# 3  City  Barrio Logan  1000 CESAR CHAVEZ WAY   CC-1005         9000
# 4  City  Barrio Logan  1000 CESAR CHAVEZ WAY   CC-1011         9000
#
#                            config_name   longitude   latitude  old longitude
# 0  30 Min Max $1.25 HR 8am-6pm Mon-Sat -118.230904  32.721670    -117.230904
# 1  30 Min Max $1.25 HR 8am-6pm Mon-Sat -118.230913  32.721575    -117.230913
# 2  2 Hour Max $1.25 HR 8am-6pm Mon-Sat -118.145178  32.700353    -117.145178
# 3  2 Hour Max $1.25 HR 8am-6pm Mon-Sat -118.145178  32.700352    -117.145178
# 4  2 Hour Max $1.25 HR 8am-6pm Mon-Sat -118.145349  32.700155    -117.145349

# %% [markdown]
# ## I was going to show you how to split off the dollar values from this column But it turns out not all the columns are fomatted the same.

# %%
#set(parking_meters['config_name'])
parking_meters['config_name'].str.split().str[3]
# Out:
# 0       $1.25
# 1       $1.25
# 2       $1.25
# 3       $1.25
# 4       $1.25
# 5       $1.25
# 6       $1.25
# 7       $1.25
# 8       $1.25
# 9       $1.25
# 10      $1.25
# 11      $1.25
# 12      $1.25
# 13      $1.25
# 14      $1.25
# 15      $1.25
# 16      $1.25
# 17      $1.25
# 18      $1.25
# 19      $1.25
# 20      $1.25
# 21      $1.25
# 22      $1.25
# 23      $1.25
# 24      $1.25
# 25      $1.25
# 26      $1.25
# 27      $1.25
# 28      $1.25
# 29      $1.25
#         ...
# 4623       of
# 4624       of
# 4625      Max
# 4626    $1.25
# 4627    $1.25
# 4628    $1.25
# 4629    $1.25
# 4630    $1.25
# 4631    $1.25
# 4632    $1.25
# 4633    $1.25
# 4634    $1.25
# 4635    $1.25
# 4636    $1.25
# 4637    $1.25
# 4638    $1.25
# 4639    $1.25
# 4640    $1.25
# 4641    $1.25
# 4642    $1.25
# 4643    $1.25
# 4644    $1.25
# 4645    $1.25
# 4646    $1.25
# 4647    $1.25
# 4648    $1.25
# 4649    $1.25
# 4650    $1.25
# 4651    $1.25
# 4652    $1.25
# Name: config_name, Length: 4653, dtype: object

# %% [markdown]
# # We will talk about cleaning up data in Pandas for next time ...
